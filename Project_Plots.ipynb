# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0.05,0.4,0.05)
changed_Ma_y = [1.0040521697370337,1.0183589419174537, 1.0779971612047017, 1.3627171338261326, 2.219407392640961, 2.838693643182597]-np.ones_like(x[:-1])
Bo_y = [1.0080111599722987, 1.5779125332470139, 2.6146061871498207, 2.7942136631112864, 3.0330569759521557, 3.4484778762502852, 2.844958011512754]-np.ones_like(x)

# %%
plt.scatter(x[:-1], changed_Ma_y)
plt.scatter(x, Bo_y)
plt.xlabel('Dimensionless number (Bo or Ma)')
plt.ylabel('Max. amplitude')
plt.legend(['Ma', 'Bo'], loc = 'upper left')
